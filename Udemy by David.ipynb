# %% [markdown]
# <h1> Udemy Courses Datasets</h1>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset/udemy_courses.csv")

# %%
#df=pd.read_csv("dataset/udemy_courses.csv",parse_dates=['published_timestamp'])

# %% [markdown]
# # 1. Display Top 10 Rows of The Dataset?

# %%
df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# # 2. Check Last 5 Rows of The Dataset?

# %%
df.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)?

# %%
df.shape
# Out:
# (3678, 12)

# %%
print("Number of Rows :",df.shape[0])
# Out:
# Number of Rows : 3678

# %%
print("Number of Columns :",df.shape[1])
# Out:
# Number of Columns : 12

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %% [markdown]
# # 5. Check Null Values In The Dataset?

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# ### Any() function use

# %%
print("any missing value is exists ?",df.isnull().values.any())
# Out:
# any missing value is exists ? False

# %% [markdown]
# # 6. Check For Duplicate Data and Drop Them?

# %%
print("Are here any duplicated value in data ? ",df.duplicated().any())
# Out:
# Are here any duplicated value in data ?  True

# %%
df[df.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# # 7. What are all different subjects for which Udemy is offering courses ?

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# # 8. Find Out Number of Courses Per Subjects?

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %% [markdown]
# # 9.Show all the courses which are Free of Cost?

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df[df['is_paid']==False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %% [markdown]
# # 10.Show all the courses which are Paid?

# %%
p=df[df['is_paid']]
p
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# # 11. Display The Count of Paid and Free Courses?

# %%
print("free courses:",df[df['is_paid']==False]['is_paid'].count())
print("paid Courses:",df[df['is_paid']]['is_paid'].count())
# Out:
# free courses: 310
# paid Courses: 3362

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %% [markdown]
# # 12. For Which Levels, Udemy Courses Providing The Courses?

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.level.value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %% [markdown]
# # 13.Which are Top Selling Courses ?

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
print(mp:= p.num_subscribers.max())
li=p.num_subscribers.to_list()
if mp in li:
    print("t")
else:
    print("f")
df[df['num_subscribers']==mp]
    
#if df['num_subscribers']==dr:
#print("ues")

# else:
#     print("no")
# Out:
# 121584
# t
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration   published_timestamp          subject
# 3230              43.0  2015-11-02T21:13:27Z  Web Development

# %%
p.sort_values(by=['num_subscribers'],ascending=False)['subject'].head(10)
# Out:
# 3230        Web Development
# 3232        Web Development
# 2619        Web Development
# 3247        Web Development
# 1979    Musical Instruments
# 3204        Web Development
# 2701        Web Development
# 3246        Web Development
# 3251        Web Development
# 2662        Web Development
# Name: subject, dtype: object

# %%
df.sort_values(by=['num_subscribers'],ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
#p.sort_values(['price'],ascending=False)

# %% [markdown]
# # 14.Which are Least Selling Courses ?

# %%
p.sort_values(by=['num_subscribers'])['subject'].head(10)
# Out:
# 886        Business Finance
# 458        Business Finance
# 459        Business Finance
# 460        Business Finance
# 461        Business Finance
# 524        Business Finance
# 462        Business Finance
# 2399    Musical Instruments
# 463        Business Finance
# 1625         Graphic Design
# Name: subject, dtype: object

# %%
p.sort_values(by=['price'])
# Out:
#       course_id                                       course_title  \
# 2343      53157                            Beginning Flute Lessons
# 916      709816     Socorro! Preciso Organizar as Minhas Finanças!
# 2286     719920              Hands-On Guitar: The Beginner's Guide
# 920     1163242  Profit and Loss Account for bankers and credit...
# 925      113712     International Trade and New Geographic Economy
# ...         ...                                                ...
# 415     1208148  Coaching Course:Investment Analysis for your c...
# 435      587232  Simple Linear Regression Analysis ( A Complete...
# 444      979616  Investing In Stocks For Big Gains, Fundamental...
# 2923    1089652  Web Application Development using Redis, Expre...
# 0       1070968                 Ultimate Investment Banking Course
#
#                                                     url  is_paid  price  \
# 2343     https://www.udemy.com/beginning-flute-lessons/     True     20
# ...

# %%
df.sort_values(by=['num_subscribers']).head(10)
# Out:
#       course_id                                       course_title  \
# 458     1258666                Financial Statement Auditing Cycles
# 2400    1026762  Coaching Course: Rhythm Instruction for Music ...
# 2401    1234656                              4 Week Rhythm Mastery
# 1236    1177156       Como Criar Logos de Sucesso - Start Designer
# 1237     177614                         Super Textos con Photoshop
# 1238    1128984         Photoshop - Aprende a Transformar Imágenes
# 1102    1251654   Understand Core Finance Principles in 60 Minutes
# 2399    1223240  Learn Pirates of the Caribbean by Ear on the P...
# 1101    1232312                  Core Financial Statement Concepts
# 2402    1214670                  Tune that Sour Note on Your Piano
#
#                                                     url  is_paid  price  \
# 458   https://www.udemy.com/financial-statement-audi...     True     50
# 2400  https://www.udemy.com/coaching-bundle-rhythm-i...     True    125
# ...

# %% [markdown]
# # 15.Show all courses of Graphic Design where the price is below 100 ?

# %%
p.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'date', 'year'],
#       dtype='object')

# %%
gd=df[df['subject']=='Graphic Design']
gd[gd['price']<100]
# Out:
#       course_id                                       course_title  \
# 1196    1197206                         Illustrator CC MasterClass
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1202      28556              Discover How to Draw and paint Comics
# 1203     317278  Typographic Logos: Typography and Lettering fo...
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...
# ...         ...                                                ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop
# 1795     496430  Infographic Design: How To Create Your Own Inf...
# 1796     793246           Autodesk Inventor 2016 : Complete Guide
# 1797     547190               Amazing Graphic Design for Beginners
#
#                                                     url  is_paid  price  \
# 1196  https://www.udemy.com/illustrator-cc-masterclass/     True     95
# ...

# %% [markdown]
# ## 2nd

# %%
df[(df['subject']=='Graphic Design') & (df['price']<100)]
# Out:
#       course_id                                       course_title  \
# 1196    1197206                         Illustrator CC MasterClass
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1202      28556              Discover How to Draw and paint Comics
# 1203     317278  Typographic Logos: Typography and Lettering fo...
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...
# ...         ...                                                ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop
# 1795     496430  Infographic Design: How To Create Your Own Inf...
# 1796     793246           Autodesk Inventor 2016 : Complete Guide
# 1797     547190               Amazing Graphic Design for Beginners
#
#                                                     url  is_paid  price  \
# 1196  https://www.udemy.com/illustrator-cc-masterclass/     True     95
# ...

# %% [markdown]
# # 16. Find Most Popular Course Title?

# %%
df.sort_values(by=['num_reviews'],ascending=False)['course_title'].head(10)
# Out:
# 3230                           The Web Developer Bootcamp
# 3232                The Complete Web Developer Course 2.0
# 3204    Angular 4 (formerly Angular 2) - The Complete ...
# 3247            JavaScript: Understanding the Weird Parts
# 3254                              Modern React with Redux
# 3246                       Learn and Understand AngularJS
# 3251                          Learn and Understand NodeJS
# 2827                 Learn HTML5 Programming From Scratch
# 3228    Angular 2 with TypeScript for Beginners: The P...
# 1979    Pianoforall - Incredible New Way To Learn Pian...
# Name: course_title, dtype: object

# %% [markdown]
# ### by subscribers

# %%
df.sort_values(by=['num_subscribers'],ascending=False)['course_title'].head(10)
# Out:
# 2827                 Learn HTML5 Programming From Scratch
# 3032                       Coding for Entrepreneurs Basic
# 3230                           The Web Developer Bootcamp
# 2783    Build Your First Website in 1 Week with HTML5 ...
# 3232                The Complete Web Developer Course 2.0
# 1896                Free Beginner Electric Guitar Lessons
# 2589    Web Design for Web Developers: Build Beautiful...
# 2619               Learn Javascript & JQuery From Scratch
# 3289    Practical PHP: Master the Basics and Code Dyna...
# 3247            JavaScript: Understanding the Weird Parts
# Name: course_title, dtype: object

# %%
df[df.num_subscribers==df.num_subscribers.max()]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# # 17. Display 10 Most Popular Courses As Per Number of Subscribers?

# %%
df.sort_values(by=['num_subscribers'],ascending=False)['subject'].head(10)
# Out:
# 2827        Web Development
# 3032        Web Development
# 3230        Web Development
# 2783        Web Development
# 3232        Web Development
# 1896    Musical Instruments
# 2589        Web Development
# 2619        Web Development
# 3289        Web Development
# 3247        Web Development
# Name: subject, dtype: object

# %%
df.sort_values(by=['num_subscribers'],ascending=False)['course_title'].head(10)
# Out:
# 2827                 Learn HTML5 Programming From Scratch
# 3032                       Coding for Entrepreneurs Basic
# 3230                           The Web Developer Bootcamp
# 2783    Build Your First Website in 1 Week with HTML5 ...
# 3232                The Complete Web Developer Course 2.0
# 1896                Free Beginner Electric Guitar Lessons
# 2589    Web Design for Web Developers: Build Beautiful...
# 2619               Learn Javascript & JQuery From Scratch
# 3289    Practical PHP: Master the Basics and Code Dyna...
# 3247            JavaScript: Understanding the Weird Parts
# Name: course_title, dtype: object

# %% [markdown]
# # 18. Find Total Number of Courses Related To Python?

# %%
# li=df.course_title.to_list()
# l1=[]
# l2=[]
# for i in li:
#     if 'python' in str.lower(i):
#         l1.append(i)
# print(l1)
# print(len(l1))
# for i in l1:
#     l2.append(df[df['course_title']==i]['subject'])
# print(l2)
# s1=pd.DataFrame(l2)
# s1
# #df[df['course_title']==s1]

# %%
cp=df[df.course_title.str.contains('python',case=False)]
print(cp['subject'].unique())
print(len(cp))
cp.groupby(['subject'])['subject'].value_counts()
# Out:
# ['Business Finance' 'Graphic Design' 'Web Development']
# 29
# subject
# Business Finance     8
# Graphic Design       1
# Web Development     20
# Name: count, dtype: int64

# %%
cp
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %% [markdown]
# # 19. Display 10 Most Popular Python Courses As Per Number of Subscribers?

# %%
cp.sort_values(by=['num_subscribers'],ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %% [markdown]
# # 20.What are courses that published in year 2015 ?

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df['date']=pd.to_datetime(df['published_timestamp'])
df.dtypes
df['year']=df.date.dt.year
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject                      date  year
# 0  2017-01-18T20:58:58Z  Business Finance 2017-01-18 20:58:58+00:00  2017

# %%
df[df['year']==2015]
# Out:
#       course_id                                       course_title  \
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 15       504036  Short Selling: Learn To Sell Stocks Before The...
# 17       564966  The Complete Chart Pattern Trading Course: A P...
# ...         ...                                                ...
# 3659     577796  Simple Javascript: Learn by Doing, Beginners W...
# 3667     523216  The Fastest Way to Create a Website Using Godaddy
# 3669     679992                  Building Better APIs with GraphQL
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3675     635248                      Learn and Build using Polymer
#
#                                                     url  is_paid  price  \
# 7     https://www.udemy.com/trading-chart-patterns-f...     True     95
# ...

# %% [markdown]
# # 21. Display Category-Wise Count of Posted Subjects [Year Wise] ?

# %%
df1=df.groupby(['year'])
df1['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         56
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          66
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       349
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       225
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64

# %% [markdown]
# ### 2nd

# %%
df.groupby(['year'])['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64

# %% [markdown]
# # 22.What are the Max. Number of Subscribers for Each Level of courses ?

# %%
lg1=df.groupby(['level']).max()


lg1['num_subscribers']#.apply(lambda x:x)['num_subscribers']#.max()#.value_counts(ascending=False)
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %% [markdown]
# ### 2nd

# %%
df.groupby(['level'])['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64
